# %% [markdown]
# ## <center style="color:Gray;">Wine Production Countries Analysis</center>

# %% [markdown]
# # <center style="color:gold">Calling libraries and data </center>

# %%
#install openpyxl to read excel file
# !pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 243 kB 282 kB/s
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
DATA_PATH = "DataSet/Wine_Production_by_country.xlsx"
data= pd.read_excel(DATA_PATH, names=["Country","Year", "Wine production in mhl"], engine='openpyxl')

# %% [markdown]
# # <center style="color:gold">Exploring the data </center>

# %% [markdown]
# #### <center>The Shape of the data</center>

# %%
data.head()
# Out:
#          Country  Year  Wine production in mhl
# 0          Italy  2012                    45.6
# 1         France  2012                    41.5
# 2          Spain  2012                    31.1
# 3  United States  2012                    21.7
# 4      Australia  2012                    12.3

# %%
data.shape
# Out:
# (120, 3)

# %% [markdown]
# #### <center>Chacking for Null</center>

# %%
data.isnull().sum()
# Out:
# Country                   0
# Year                      0
# Wine production in mhl    0
# dtype: int64

# %% [markdown]
# #### <center>Exploring the features</center>

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Wine production in mhl'], dtype='object')

# %%
countires= data.Country.unique()
print(countires)
print(len(countires))
# Out:
# ['Italy' 'France' 'Spain' 'United States' 'Australia' 'China'
#  'South Africa' 'Chile' 'Argentina' 'Germany' 'Portugal' 'Russia'
#  'Romania' 'New Zealand' 'Greece' 'Serbia' 'Austria' 'Hungary' 'Moldova'
#  'Brazil' 'Bulgaria' 'Georgia' 'Switzerland' 'World total']
# 24

# %% [markdown]
# #### <center>Change to date data type</center>

# %%
data['Year']= pd.to_datetime(data["Year"])

# %%
data.dtypes
# Out:
# Country                           object
# Year                      datetime64[ns]
# Wine production in mhl           float64
# dtype: object

# %%
data.describe().transpose()
# Out:
#                         count       mean        std  min  25%  50%     75%  \
# Wine production in mhl  120.0  22.135833  54.147233  0.7  2.3  6.1  12.925
#
#                           max
# Wine production in mhl  290.0

# %% [markdown]
# # <center style="color:gold">Exploration Report </center>

# %% [markdown]
# - #### We have 120 line and 3  features
# - #### No null Values
# - #### the countries we have (24):
#     - 'Italy'
#     - 'France'
#     - 'Spain'
#     - 'United States'
#     - 'Australia'
#     - 'China'
#     - 'South Africa'
#     - 'Chile'
#     - 'Argentina'
#     - 'Germany'
#     - 'Portugal'
#     - 'Russia'
#     - 'Romania'
#     - 'New Zealand'
#     - 'Greece'
#     - 'Serbia'
#     - 'Austria'
#     - 'Hungary'
#     - 'Moldova'
#     - 'Brazil'
#     - 'Bulgaria'
#     - 'Georgia'
#     - 'Switzerland'
#     - 'World total'

# %% [markdown]
# # <center style="color:gold">Data Visualization </center>

# %%
data.hist(figsize=(15,5))
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Wine production in mhl'}>]],
#       dtype=object)

# %%
data['Year'] = data['Year'].astype(int)

# %%
plt.figure(figsize=(10,10))
plot =sns.barplot(data['Year'], data["Wine production in mhl"])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10,10))
plot =sns.barplot(data['Year'], data["Country"])
plot.set(xlim=(data['Year'].min(), data['Year'].max()))
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [(2012.0, 2016.0)]

# %%
data['Country'].value_counts().plot(kind='pie', figsize=(10,10), autopct="%1.2f%%")
plt.title("Country Pie")
plt.show()

# %% [markdown]
# ### All the countries have the same percenet of production

# %%
data['Wine production in mhl'].value_counts().plot(kind='pie', figsize=(10,10), autopct="%1.2f%%")
plt.title("Wine production in mhl Pie")
plt.show()

# %% [markdown]
# # <center style="color:red">Note</center>
# ### **By looking to the pie we can see that 2.3 is the most value repated in the data set so let's take it as our refference because too much production means too much using for this 2.3 is the most wanted type and we will see which country make production more.**

# %%
data_hight= data.loc[data["Wine production in mhl"]==2.3]

# %%
data_hight['Country'].value_counts().plot(kind='pie', figsize=(10,10), autopct="%1.2f%%")
plt.title("Country Pie")
plt.show()

# %% [markdown]
# # <center style="color:gold">Serbia is the most producer</center>

# %% [markdown]
# <center><img src="https://i.gifer.com/9ipP.gif"></center>
